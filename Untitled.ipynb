# %%
import easyocr
import os
# import matplotlib.pyplot as plt
# import cv2
from IPython.display import Image, display
import warnings

# Filter out the specific warning message


def count_files_in_folder(folder_path):
    file_count = 0

    try:
        files = os.listdir(folder_path)
        for file in files:
            if os.path.isfile(os.path.join(folder_path, file)):
                file_count += 1
        return file_count
    except OSError as e:
        print("Error:", e)
        return None


folder_path = "cars/"
file_count = count_files_in_folder(folder_path)


for counting in range(file_count):
    display(Image('plates/scaned_img_'+str(counting)+'.jpg'))

    reader = easyocr.Reader(['en'])

    output = reader.readtext('plates/scaned_img_'+str(counting)+'.jpg') 

    # recognized_texts = [item[1] for item in output]
    # print(recognized_texts)

    # print(output)

    extracted_texts = []

    for item in output:
        text = item[1]
        if isinstance(text, str):
            extracted_texts.append(text)
        elif isinstance(text, list):
            sub_text = ' '.join(
                sub_item for sub_item in text if isinstance(sub_item, str))
            extracted_texts.append(sub_text)

    for text in extracted_texts:
        print(text)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# R3s;
# TTS52o1
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MB
# 0L0
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 'up53000633
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# DL9CAK7 799
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 824
# TnO9BT
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MH 04 JM 8765
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# IND
# HRZGDK8337|
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# OEE5o1
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# BRABUS
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# LR33 TEE
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MHA7@6
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MH 04 JM 8765
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# up52000623
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# D44DDY

# %%
import easyocr
import os
# import matplotlib.pyplot as plt
# import cv2
from IPython.display import Image, display
import warnings

# Filter out the specific warning message


def count_files_in_folder(folder_path):
    file_count = 0

    try:
        files = os.listdir(folder_path)
        for file in files:
            if os.path.isfile(os.path.join(folder_path, file)):
                file_count += 1
        return file_count
    except OSError as e:
        print("Error:", e)
        return None


folder_path = "cars/"
file_count = count_files_in_folder(folder_path)


for counting in range(file_count):
    display(Image('plates/scaned_img_'+str(counting)+'.jpg'))

    reader = easyocr.Reader(['en'])

    output = reader.readtext('plates/scaned_img_'+str(counting)+'.jpg') 

    # recognized_texts = [item[1] for item in output]
    # print(recognized_texts)

    # print(output)

    extracted_texts = []

    for item in output:
        text = item[1]
        if isinstance(text, str):
            extracted_texts.append(text)
        elif isinstance(text, list):
            sub_text = ' '.join(
                sub_item for sub_item in text if isinstance(sub_item, str))
            extracted_texts.append(sub_text)

    for text in extracted_texts:
        print(text)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# R3s;
# TTS52o1
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MB
# 0L0
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 'up53000633
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# DL9CAK7 799
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 824
# TnO9BT
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MH 04 JM 8765
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# IND
# HRZGDK8337|
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# OEE5o1
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# BRABUS
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# LR33 TEE
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MHA7@6
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MH 04 JM 8765
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\display.py:1045, in Image._data_and_metadata(self, always_both)
#    1044 try:
# -> 1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\formatters.py:974, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     971     method = get_real_method(obj, self.print_method)
#     973     if method is not None:
# --> 974         return method(include=include, exclude=exclude)
#     975     return None
#     976 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\display.py:1035, in Image._repr_mimebundle_(self, include, exclude)
#    1033 if self.embed:
#    1034     mimetype = self._mimetype
# -> 1035     data, metadata = self._data_and_metadata(always_both=True)
#    1036     if metadata:
#    1037         metadata = {mimetype: metadata}
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\display.py:1047, in Image._data_and_metadata(self, always_both)
#    1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
# -> 1047     raise FileNotFoundError(
#    1048         "No such file or directory: '%s'" % (self.data)) from e
#    1049 md = {}
#    1050 if self.metadata:
#
# FileNotFoundError: No such file or directory: 'plates/scaned_img_12.jpg'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\display.py:1045, in Image._data_and_metadata(self, always_both)
#    1044 try:
# -> 1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\display.py:1067, in Image._repr_png_(self)
#    1065 def _repr_png_(self):
#    1066     if self.embed and self.format == self._FMT_PNG:
# -> 1067         return self._data_and_metadata()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\display.py:1047, in Image._data_and_metadata(self, always_both)
#    1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
# -> 1047     raise FileNotFoundError(
#    1048         "No such file or directory: '%s'" % (self.data)) from e
#    1049 md = {}
#    1050 if self.metadata:
#
# FileNotFoundError: No such file or directory: 'plates/scaned_img_12.jpg'
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 34
#      30 display(Image('plates/scaned_img_'+str(counting)+'.jpg'))
#      32 reader = easyocr.Reader(['en'])
# ---> 34 output = reader.readtext('plates/scaned_img_'+str(counting)+'.jpg')
#      36 # recognized_texts = [item[1] for item in output]
#      37 # print(recognized_texts)
#      38
#      39 # print(output)
#      41 extracted_texts = []
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\easyocr\easyocr.py:450, in Reader.readtext(self, image, decoder, beamWidth, batch_size, workers, allowlist, blocklist, detail, rotation_info, paragraph, min_size, contrast_ths, adjust_contrast, filter_ths, text_threshold, low_text, link_threshold, canvas_size, mag_ratio, slope_ths, ycenter_ths, height_ths, width_ths, y_ths, x_ths, add_margin, threshold, bbox_min_score, bbox_min_size, max_candidates, output_format)
#     436 def readtext(self, image, decoder = 'greedy', beamWidth= 5, batch_size = 1,\
#     437              workers = 0, allowlist = None, blocklist = None, detail = 1,\
#     438              rotation_info = None, paragraph = False, min_size = 20,\
#    (...)
#     444              threshold = 0.2, bbox_min_score = 0.2, bbox_min_size = 3, max_candidates = 0,
#     445              output_format='standard'):
#     446     '''
#     447     Parameters:
#     448     image: file path or numpy-array or a byte stream object
#     449     '''
# --> 450     img, img_cv_grey = reformat_input(image)
#     452     horizontal_list, free_list = self.detect(img,
#     453                                              min_size = min_size, text_threshold = text_threshold,\
#     454                                              low_text = low_text, link_threshold = link_threshold,\
#    (...)
#     460                                              bbox_min_size = bbox_min_size, max_candidates = max_candidates
#     461                                              )
#     462     # get the 1st result from hor & free list as self.detect returns a list of depth 3
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\easyocr\utils.py:741, in reformat_input(image)
#     739         img_cv_grey = cv2.imread(image, cv2.IMREAD_GRAYSCALE)
#     740         image = os.path.expanduser(image)
# --> 741     img = loadImage(image)  # can accept URL
#     742 elif type(image) == bytes:
#     743     nparr = np.frombuffer(image, np.uint8)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\easyocr\imgproc.py:12, in loadImage(img_file)
#      11 def loadImage(img_file):
# ---> 12     img = io.imread(img_file)           # RGB order
#      13     if img.shape[0] == 2: img = img[0]
#      14     if len(img.shape) == 2 : img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\skimage\io\_io.py:53, in imread(fname, as_gray, plugin, **plugin_args)
#      50         plugin = 'tifffile'
#      52 with file_or_url_context(fname) as fname:
# ---> 53     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      55 if not hasattr(img, 'ndim'):
#      56     return img
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\skimage\io\manage_plugins.py:205, in call_plugin(kind, *args, **kwargs)
#     202     except IndexError:
#     203         raise RuntimeError(f'Could not find the plugin "{plugin}" for {kind}.')
# --> 205 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\skimage\io\_plugins\imageio_plugin.py:11, in imread(*args, **kwargs)
#       9 @wraps(imageio_imread)
#      10 def imread(*args, **kwargs):
# ---> 11     out = np.asarray(imageio_imread(*args, **kwargs))
#      12     if not out.flags['WRITEABLE']:
#      13         out = out.copy()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\imageio\v3.py:53, in imread(uri, index, plugin, extension, format_hint, **kwargs)
#      50 if index is not None:
#      51     call_kwargs["index"] = index
# ---> 53 with imopen(uri, "r", **plugin_kwargs) as img_file:
#      54     return np.asarray(img_file.read(**call_kwargs))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\imageio\core\imopen.py:113, in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     111     request.format_hint = format_hint
#     112 else:
# --> 113     request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     115 source = "<bytes>" if isinstance(uri, bytes) else uri
#     117 # fast-path based on plugin
#     118 # (except in legacy mode)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\imageio\core\request.py:247, in Request.__init__(self, uri, mode, extension, format_hint, **kwargs)
#     244     raise ValueError(f"Invalid Request.Mode: {mode}")
#     246 # Parse what was given
# --> 247 self._parse_uri(uri)
#     249 # Set extension
#     250 if extension is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\imageio\core\request.py:407, in Request._parse_uri(self, uri)
#     404 if is_read_request:
#     405     # Reading: check that the file exists (but is allowed a dir)
#     406     if not os.path.exists(fn):
# --> 407         raise FileNotFoundError("No such file: '%s'" % fn)
#     408 else:
#     409     # Writing: check that the directory to write to does exist
#     410     dn = os.path.dirname(fn)
#
# FileNotFoundError: No such file: 'D:\Number-Plate\plates\scaned_img_12.jpg'

# %%
import easyocr
import os
# import matplotlib.pyplot as plt
# import cv2
from IPython.display import Image, display
import warnings

# Filter out the specific warning message


def count_files_in_folder(folder_path):
    file_count = 0

    try:
        files = os.listdir(folder_path)
        for file in files:
            if os.path.isfile(os.path.join(folder_path, file)):
                file_count += 1
        return file_count
    except OSError as e:
        print("Error:", e)
        return None


folder_path = "cars/"
file_count = count_files_in_folder(folder_path)


for counting in range(file_count):
    display(Image('plates/scaned_img_'+str(counting)+'.jpg'))

    reader = easyocr.Reader(['en'])

    output = reader.readtext('plates/scaned_img_'+str(counting)+'.jpg') 

    # recognized_texts = [item[1] for item in output]
    # print(recognized_texts)

    # print(output)

    extracted_texts = []

    for item in output:
        text = item[1]
        if isinstance(text, str):
            extracted_texts.append(text)
        elif isinstance(text, list):
            sub_text = ' '.join(
                sub_item for sub_item in text if isinstance(sub_item, str))
            extracted_texts.append(sub_text)

    for text in extracted_texts:
        print(text)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# R3s;
# TTS52o1
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MB
# 0L0
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# OEE5o1
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# BRABUS
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# LR33 TEE
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MHA7@6
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MH 04 JM 8765
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# D44DDY
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 'up53000633
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# DL9CAK7 799
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 824
# TnO9BT
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\display.py:1045, in Image._data_and_metadata(self, always_both)
#    1044 try:
# -> 1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\formatters.py:974, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     971     method = get_real_method(obj, self.print_method)
#     973     if method is not None:
# --> 974         return method(include=include, exclude=exclude)
#     975     return None
#     976 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\display.py:1035, in Image._repr_mimebundle_(self, include, exclude)
#    1033 if self.embed:
#    1034     mimetype = self._mimetype
# -> 1035     data, metadata = self._data_and_metadata(always_both=True)
#    1036     if metadata:
#    1037         metadata = {mimetype: metadata}
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\display.py:1047, in Image._data_and_metadata(self, always_both)
#    1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
# -> 1047     raise FileNotFoundError(
#    1048         "No such file or directory: '%s'" % (self.data)) from e
#    1049 md = {}
#    1050 if self.metadata:
#
# FileNotFoundError: No such file or directory: 'plates/scaned_img_11.jpg'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\display.py:1045, in Image._data_and_metadata(self, always_both)
#    1044 try:
# -> 1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\display.py:1067, in Image._repr_png_(self)
#    1065 def _repr_png_(self):
#    1066     if self.embed and self.format == self._FMT_PNG:
# -> 1067         return self._data_and_metadata()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\display.py:1047, in Image._data_and_metadata(self, always_both)
#    1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
# -> 1047     raise FileNotFoundError(
#    1048         "No such file or directory: '%s'" % (self.data)) from e
#    1049 md = {}
#    1050 if self.metadata:
#
# FileNotFoundError: No such file or directory: 'plates/scaned_img_11.jpg'
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 34
#      30 display(Image('plates/scaned_img_'+str(counting)+'.jpg'))
#      32 reader = easyocr.Reader(['en'])
# ---> 34 output = reader.readtext('plates/scaned_img_'+str(counting)+'.jpg')
#      36 # recognized_texts = [item[1] for item in output]
#      37 # print(recognized_texts)
#      38
#      39 # print(output)
#      41 extracted_texts = []
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\easyocr\easyocr.py:450, in Reader.readtext(self, image, decoder, beamWidth, batch_size, workers, allowlist, blocklist, detail, rotation_info, paragraph, min_size, contrast_ths, adjust_contrast, filter_ths, text_threshold, low_text, link_threshold, canvas_size, mag_ratio, slope_ths, ycenter_ths, height_ths, width_ths, y_ths, x_ths, add_margin, threshold, bbox_min_score, bbox_min_size, max_candidates, output_format)
#     436 def readtext(self, image, decoder = 'greedy', beamWidth= 5, batch_size = 1,\
#     437              workers = 0, allowlist = None, blocklist = None, detail = 1,\
#     438              rotation_info = None, paragraph = False, min_size = 20,\
#    (...)
#     444              threshold = 0.2, bbox_min_score = 0.2, bbox_min_size = 3, max_candidates = 0,
#     445              output_format='standard'):
#     446     '''
#     447     Parameters:
#     448     image: file path or numpy-array or a byte stream object
#     449     '''
# --> 450     img, img_cv_grey = reformat_input(image)
#     452     horizontal_list, free_list = self.detect(img,
#     453                                              min_size = min_size, text_threshold = text_threshold,\
#     454                                              low_text = low_text, link_threshold = link_threshold,\
#    (...)
#     460                                              bbox_min_size = bbox_min_size, max_candidates = max_candidates
#     461                                              )
#     462     # get the 1st result from hor & free list as self.detect returns a list of depth 3
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\easyocr\utils.py:741, in reformat_input(image)
#     739         img_cv_grey = cv2.imread(image, cv2.IMREAD_GRAYSCALE)
#     740         image = os.path.expanduser(image)
# --> 741     img = loadImage(image)  # can accept URL
#     742 elif type(image) == bytes:
#     743     nparr = np.frombuffer(image, np.uint8)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\easyocr\imgproc.py:12, in loadImage(img_file)
#      11 def loadImage(img_file):
# ---> 12     img = io.imread(img_file)           # RGB order
#      13     if img.shape[0] == 2: img = img[0]
#      14     if len(img.shape) == 2 : img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\skimage\io\_io.py:53, in imread(fname, as_gray, plugin, **plugin_args)
#      50         plugin = 'tifffile'
#      52 with file_or_url_context(fname) as fname:
# ---> 53     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      55 if not hasattr(img, 'ndim'):
#      56     return img
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\skimage\io\manage_plugins.py:205, in call_plugin(kind, *args, **kwargs)
#     202     except IndexError:
#     203         raise RuntimeError(f'Could not find the plugin "{plugin}" for {kind}.')
# --> 205 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\skimage\io\_plugins\imageio_plugin.py:11, in imread(*args, **kwargs)
#       9 @wraps(imageio_imread)
#      10 def imread(*args, **kwargs):
# ---> 11     out = np.asarray(imageio_imread(*args, **kwargs))
#      12     if not out.flags['WRITEABLE']:
#      13         out = out.copy()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\imageio\v3.py:53, in imread(uri, index, plugin, extension, format_hint, **kwargs)
#      50 if index is not None:
#      51     call_kwargs["index"] = index
# ---> 53 with imopen(uri, "r", **plugin_kwargs) as img_file:
#      54     return np.asarray(img_file.read(**call_kwargs))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\imageio\core\imopen.py:113, in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     111     request.format_hint = format_hint
#     112 else:
# --> 113     request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     115 source = "<bytes>" if isinstance(uri, bytes) else uri
#     117 # fast-path based on plugin
#     118 # (except in legacy mode)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\imageio\core\request.py:247, in Request.__init__(self, uri, mode, extension, format_hint, **kwargs)
#     244     raise ValueError(f"Invalid Request.Mode: {mode}")
#     246 # Parse what was given
# --> 247 self._parse_uri(uri)
#     249 # Set extension
#     250 if extension is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\imageio\core\request.py:407, in Request._parse_uri(self, uri)
#     404 if is_read_request:
#     405     # Reading: check that the file exists (but is allowed a dir)
#     406     if not os.path.exists(fn):
# --> 407         raise FileNotFoundError("No such file: '%s'" % fn)
#     408 else:
#     409     # Writing: check that the directory to write to does exist
#     410     dn = os.path.dirname(fn)
#
# FileNotFoundError: No such file: 'D:\Number-Plate\plates\scaned_img_11.jpg'

# %%
import easyocr
import os
# import matplotlib.pyplot as plt
# import cv2
from IPython.display import Image, display
import warnings

# Filter out the specific warning message


def count_files_in_folder(folder_path):
    file_count = 0

    try:
        files = os.listdir(folder_path)
        for file in files:
            if os.path.isfile(os.path.join(folder_path, file)):
                file_count += 1
        return file_count
    except OSError as e:
        print("Error:", e)
        return None


folder_path = "cars/"
file_count = count_files_in_folder(folder_path)


for counting in range(file_count):
    display(Image('plates/scaned_img_'+str(counting)+'.jpg'))

    reader = easyocr.Reader(['en'])

    output = reader.readtext('plates/scaned_img_'+str(counting)+'.jpg') 

    # recognized_texts = [item[1] for item in output]
    # print(recognized_texts)

    # print(output)

    extracted_texts = []

    for item in output:
        text = item[1]
        if isinstance(text, str):
            extracted_texts.append(text)
        elif isinstance(text, list):
            sub_text = ' '.join(
                sub_item for sub_item in text if isinstance(sub_item, str))
            extracted_texts.append(sub_text)

    for text in extracted_texts:
        print(text)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# R3s;
# TTS52o1
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MB
# 0L0
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# OEE5o1
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# BRABUS
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# LR33 TEE
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MHA7@6
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MH 04 JM 8765
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# D44DDY
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 'up53000633
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# DL9CAK7 799
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 824
# TnO9BT
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# TN11AE 4710
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# IND
# HRZGDK8337|

# %%
import easyocr
import os
# import matplotlib.pyplot as plt
# import cv2
from IPython.display import Image, display
import warnings

# Filter out the specific warning message


def count_files_in_folder(folder_path):
    file_count = 0

    try:
        files = os.listdir(folder_path)
        for file in files:
            if os.path.isfile(os.path.join(folder_path, file)):
                file_count += 1
        return file_count
    except OSError as e:
        print("Error:", e)
        return None


folder_path = "cars/"
file_count = count_files_in_folder(folder_path)


for counting in range(file_count):
    display(Image('plates/scaned_img_'+str(counting)+'.jpg'))

    reader = easyocr.Reader(['en'])

    output = reader.readtext('plates/scaned_img_'+str(counting)+'.jpg') 

    # recognized_texts = [item[1] for item in output]
    # print(recognized_texts)

    # print(output)

    extracted_texts = []

    for item in output:
        text = item[1]
        if isinstance(text, str):
            extracted_texts.append(text)
        elif isinstance(text, list):
            sub_text = ' '.join(
                sub_item for sub_item in text if isinstance(sub_item, str))
            extracted_texts.append(sub_text)

    for text in extracted_texts:
        print(text)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# R3s;
# TTS52o1
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MB
# 0L0
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# D44DDY
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 'up53000633
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# DL9CAK7 799
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# KLOaay 4210
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 824
# TnO9BT
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# TN11AE 4710
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# IND
# HRZGDK8337|
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# OEE5o1
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# BRABUS
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# LR33 TEE
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MHA7@6
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MH 04 JM 8765

# %%
import easyocr
import os
# import matplotlib.pyplot as plt
# import cv2
from IPython.display import Image, display
import warnings

# Filter out the specific warning message


def count_files_in_folder(folder_path):
    file_count = 0

    try:
        files = os.listdir(folder_path)
        for file in files:
            if os.path.isfile(os.path.join(folder_path, file)):
                file_count += 1
        return file_count
    except OSError as e:
        print("Error:", e)
        return None


folder_path = "cars/"
file_count = count_files_in_folder(folder_path)


for counting in range(file_count):
    display(Image('plates/scaned_img_'+str(counting)+'.jpg'))

    reader = easyocr.Reader(['en'])

    output = reader.readtext('plates/scaned_img_'+str(counting)+'.jpg') 

    # recognized_texts = [item[1] for item in output]
    # print(recognized_texts)

    # print(output)

    extracted_texts = []

    for item in output:
        text = item[1]
        if isinstance(text, str):
            extracted_texts.append(text)
        elif isinstance(text, list):
            sub_text = ' '.join(
                sub_item for sub_item in text if isinstance(sub_item, str))
            extracted_texts.append(sub_text)

    for text in extracted_texts:
        print(text)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# TN TS52o1
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MB
# 0L0
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# KLOaay 4210
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 824
# TnO9BT
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# TN11AE 4710
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# IND
# HRZGDK8337|
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# OEE5o1
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# JHOZBA 0993
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# PB7340712
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MHA3LEU 1172
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# BRABUS
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# PB3ZV 0356]
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# GJ05RF9259
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 526188
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MH 04 JM 8765
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# BASHA CFRI
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# TN05 BD
# 8784
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# PAS21L 1617
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# UP7QFNO309
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Ino
# '6J098H1441)
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# T910BJ4E
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# LR33 TEE
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MHA7@6
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# MH 04 JM 8765
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# D44DDY
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 'up53000633
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# DL9CAK7 799
